# %%
file = open('data.csv','x')
file.close()

# %%
try:
    file = open('data.csv','x')
    file.close()
except:
    print("The file name already exist")
# Out:
# The file name already exist

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    Sn    Name  Age          Add
# 0   1     Ram   34   Chakrapath
# 1   2   Shyam   89   Kaushaltar
# 2   3    Hari   31     Lazimpat
# 3   4   Nabin   32    Maitidevi
# 4   5    Raju   45     Chabahil
# 5   6  Tripti   42  Chhetrapati

# %%
df.head()
# Out:
#    Sn   Name  Age         Add
# 0   1    Ram   34  Chakrapath
# 1   2  Shyam   89  Kaushaltar
# 2   3   Hari   31    Lazimpat
# 3   4  Nabin   32   Maitidevi
# 4   5   Raju   45    Chabahil

# %%
df.tail()
# Out:
#    Sn    Name  Age          Add
# 1   2   Shyam   89   Kaushaltar
# 2   3    Hari   31     Lazimpat
# 3   4   Nabin   32    Maitidevi
# 4   5    Raju   45     Chabahil
# 5   6  Tripti   42  Chhetrapati

# %%
df.head(3)
# Out:
#    Sn   Name  Age         Add
# 0   1    Ram   34  Chakrapath
# 1   2  Shyam   89  Kaushaltar
# 2   3   Hari   31    Lazimpat

# %%
df.tail(2)
# Out:
#    Sn    Name  Age          Add
# 4   5    Raju   45     Chabahil
# 5   6  Tripti   42  Chhetrapati

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows=3)
df
# Out:
#    Sn   Name  Age         Add
# 0   1    Ram   34  Chakrapath
# 1   2  Shyam   89  Kaushaltar
# 2   3   Hari   31    Lazimpat

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df
# Out:
#       Name  Age          Add
# Sn
# 1      Ram   34   Chakrapath
# 2    Shyam   89   Kaushaltar
# 3     Hari   31     Lazimpat
# 4    Nabin   32    Maitidevi
# 5     Raju   45     Chabahil
# 6   Tripti   42  Chhetrapati

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn',usecols = ['Sn','Name','Age'])
df
# Out:
#       Name  Age
# Sn
# 1      Ram   34
# 2    Shyam   89
# 3     Hari   31
# 4    Nabin   32
# 5     Raju   45
# 6   Tripti   42

# %%
#Selecting Rows

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df.iloc[1:4]
# Out:
#      Name  Age         Add
# Sn
# 2   Shyam   89  Kaushaltar
# 3    Hari   31    Lazimpat
# 4   Nabin   32   Maitidevi

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df.iloc[1:4,0:2]
# Out:
#      Name  Age
# Sn
# 2   Shyam   89
# 3    Hari   31
# 4   Nabin   32

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df.loc[2:5]
# Out:
#      Name  Age         Add
# Sn
# 2   Shyam   89  Kaushaltar
# 3    Hari   31    Lazimpat
# 4   Nabin   32   Maitidevi
# 5    Raju   45    Chabahil

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df.loc[2:5,"Sn":"Age"]
# Out:
#      Name  Age
# Sn
# 2   Shyam   89
# 3    Hari   31
# 4   Nabin   32
# 5    Raju   45

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Name')
df.loc['Ram':'Raju']
# Out:
#        Sn  Age         Add
# Name
# Ram     1   34  Chakrapath
# Shyam   2   89  Kaushaltar
# Hari    3   31    Lazimpat
# Nabin   4   32   Maitidevi
# Raju    5   45    Chabahil

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
list(df['Name'])
# Out:
# ['Ram', 'Shyam', 'Hari', 'Nabin', 'Raju', 'Tripti']

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df[df['Name'] == 'Ram']
# Out:
#    Name  Age         Add
# Sn
# 1   Ram   34  Chakrapath

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df[df['Age'] > 34]
# Out:
#       Name  Age          Add
# Sn
# 2    Shyam   89   Kaushaltar
# 5     Raju   45     Chabahil
# 6   Tripti   42  Chhetrapati

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df[(df['Add'] == 'Chakrapath') & (df['Age']>30)]
# Out:
#    Name  Age         Add
# Sn
# 1   Ram   34  Chakrapath

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df[(df['Add'] == 'Chakrapath') | (df['Age']>30)]
# Out:
#       Name  Age          Add
# Sn
# 1      Ram   34   Chakrapath
# 2    Shyam   89   Kaushaltar
# 3     Hari   31     Lazimpat
# 4    Nabin   32    Maitidevi
# 5     Raju   45     Chabahil
# 6   Tripti   42  Chhetrapati

# %%
import pandas as pd
df = pd.read_csv('data.csv', index_col ='Sn')
df = df[(df['Add'] == 'Chabahil') | (df['Age']>40)]
df.to_csv('new_data.csv')
df
# Out:
#       Name  Age          Add
# Sn
# 2    Shyam   89   Kaushaltar
# 5     Raju   45     Chabahil
# 6   Tripti   42  Chhetrapati

# %%
#using dataframe

# %%
import pandas as pd
data = {'Name':['Ram','Hari','Rishav','Neha'],
       'Address':['Kathmandu','Bhaktapur','Palpa','Lalitpur'],
       'Age':[21,45,32,52]}
df = pd.DataFrame(data)
df.to_csv('boooks.csv')
df.head()
df
# Out:
#      Name    Address  Age
# 0     Ram  Kathmandu   21
# 1    Hari  Bhaktapur   45
# 2  Rishav      Palpa   32
# 3    Neha   Lalitpur   52
